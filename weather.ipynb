# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

data = pd.read_csv("clothing_weather.csv")
data
# Out:
#     temp_c  temp_f rain snow     outerwear          top  bottom  overall
# 0    -12.2    10.0   no   no  heavy jacket      sweater   pants        7
# 1     -5.6    22.0   no  yes  heavy jacket  long sleeve   pants       72
# 2     -1.7    29.0  yes   no  heavy jacket  long sleeve   pants       71
# 3      1.7    35.0   no   no  heavy jacket  long sleeve   pants        7
# 4      5.0    41.0  yes   no  heavy jacket  long sleeve   pants       71
# ..     ...     ...  ...  ...           ...          ...     ...      ...
# 92    35.0    95.0   no   no          none       tshirt  shorts        1
# 93    36.0    96.8  yes   no          none       tshirt  shorts       11
# 94    37.0    98.6   no   no          none       tshirt  shorts        1
# 95    38.0   100.4   no   no          none       tshirt  shorts        1
# 96    39.0   102.2   no   no          none       tshirt  shorts        1
#
# [97 rows x 8 columns]

# %%
data["rain"] = data["rain"].replace("no", 0)
data["rain"] = data["rain"].replace("yes", 1)
data["snow"] = data["rain"].replace("no", 0)
data["snow"] = data["rain"].replace("yes", 1)
data
# Out:
#     temp_c  temp_f  rain  snow     outerwear          top  bottom  overall
# 0    -12.2    10.0     0     0  heavy jacket      sweater   pants        7
# 1     -5.6    22.0     0     0  heavy jacket  long sleeve   pants       72
# 2     -1.7    29.0     1     1  heavy jacket  long sleeve   pants       71
# 3      1.7    35.0     0     0  heavy jacket  long sleeve   pants        7
# 4      5.0    41.0     1     1  heavy jacket  long sleeve   pants       71
# ..     ...     ...   ...   ...           ...          ...     ...      ...
# 92    35.0    95.0     0     0          none       tshirt  shorts        1
# 93    36.0    96.8     1     1          none       tshirt  shorts       11
# 94    37.0    98.6     0     0          none       tshirt  shorts        1
# 95    38.0   100.4     0     0          none       tshirt  shorts        1
# 96    39.0   102.2     0     0          none       tshirt  shorts        1
#
# [97 rows x 8 columns]

# %%
feature_cols = ['temp_f','rain','snow']
X = data[feature_cols] # Features
y = data.overall # Target variabley

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6666666666666666
